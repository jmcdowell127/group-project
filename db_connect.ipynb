# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import extract

# %%
db=sqlalchemy.create_engine("sqlite:///movies.sqlite")
pd.read_sql('select * from movies',db)
# Out:
#       field1    ID                                     Title  Year   Age  \
# 0          0     1                              The Irishman  2019   18+
# 1          1     2                                    Dangal  2016    7+
# 2          2     3  David Attenborough: A Life on Our Planet  2020    7+
# 3          3     4         Lagaan: Once Upon a Time in India  2001    7+
# 4          4     5                                      Roma  2018   18+
# ...      ...   ...                                       ...   ...   ...
# 9510    9510  9511                        Most Wanted Sharks  2020  None
# 9511    9511  9512             Doc McStuffins: The Doc Is In  2020  None
# 9512    9512  9513                     Ultimate Viking Sword  2019  None
# 9513    9513  9514           Hunt for the Abominable Snowman  2011  None
# 9514    9514  9515       Women of Impact: Changing the World  2019    7+
#
#         IMDb RottenTomatoes  Netflix  Hulu  PrimeVideo  Disney+  Type  \
# 0     7.8/10         98/100        1     0           0        0     0
# 1     8.4/10         97/100        1     0           0        0     0
# 2     9.0/10         95/100        1     0           0        0     0
# 3     8.1/10         94/100        1     0           0        0     0
# 4     7.7/10         94/100        1     0           0        0     0
# ...      ...            ...      ...   ...         ...      ...   ...
# 9510    None         14/100        0     0           0        1     0
# 9511    None         13/100        0     0           0        1     0
# 9512    None         13/100        0     0           0        1     0
# 9513    None         10/100        0     0           0        1     0
# 9514    None         10/100        0     0           0        1     0
#
#                                               Directors  \
# 0                                       Martin Scorsese
# 1                                         Nitesh Tiwari
# 2     Alastair Fothergill,Jonathan Hughes,Keith Scholey
# 3                                    Ashutosh Gowariker
# 4                                                  None
# ...                                                 ...
# 9510                                               None
# 9511                             Chris Anthony Hamilton
# 9512                                               None
# 9513                                         Dan Oliver
# 9514                                          Lisa Feit
#
#                                 Genres  \
# 0                Biography,Crime,Drama
# 1         Action,Biography,Drama,Sport
# 2                Documentary,Biography
# 3                  Drama,Musical,Sport
# 4     Action,Drama,History,Romance,War
# ...                                ...
# 9510                  Crime,Reality-TV
# 9511                         Animation
# 9512                              None
# 9513                     Drama,History
# 9514                       Documentary
#
#                                                 Country  \
# 0                                         United States
# 1     India,United States,United Kingdom,Australia,K...
# 2                                        United Kingdom
# 3                                  India,United Kingdom
# 4                          United Kingdom,United States
# ...                                                 ...
# 9510                                      United States
# 9511                                      United States
# 9512                                      United States
# 9513                                               None
# 9514                                      United States
#
#                                   Language  Runtime
# 0     English,Italian,Latin,Spanish,German    209.0
# 1                            Hindi,English    161.0
# 2                                  English     83.0
# 3                            Hindi,English    224.0
# 4                                  English     52.0
# ...                                    ...      ...
# 9510                         Greek,English      NaN
# 9511                               English     23.0
# 9512                                  None      NaN
# 9513                                  None      NaN
# 9514                               English      NaN
#
# [9515 rows x 17 columns]
